# %% [markdown]
# # 1. Importamos el conector (Framework Connector)
# # En el curso usan ChatNVIDIA, tú usarás el de Google para Gemma 4

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA
import os

# %%
llm = ChatNVIDIA(model="google/gemma-4-31b-it")

# %%
prompt = "Hola Gemma, explícame brevemente quien es mil mascaras?"

print(f"--- Consultando a: {llm.model} ---\n")

try:
    # El streaming permite ver la respuesta fluida como en el curso
    for chunk in llm.stream(prompt):
        print(chunk.content, end="", flush=True)
except Exception as e:
    print(f"\n[ERROR]: No se pudo conectar con el modelo. Detalle: {e}")
# Out:
# --- Consultando a: google/gemma-4-31b-it ---
#
# **Mil Máscaras** (nombre real: José dynasty) es una leyenda de la lucha libre profesional, originaria de México. Es reconocido mundialmente como uno de los luchadores más influyentes y respetados de la historia.
#
# Aquí tienes los puntos clave para entender quién es:
#
# 1.  **El "Embajador" de la Lucha Libre:** Fue uno de los primeros luchadores mexicanos en alcanzar fama internacional, triunfando no solo en México, sino también en Japón y Estados Unidos.
# 2.  **El Nombre:** Se hace llamar "Mil Máscaras" porque, según la leyenda, posee una colección inmensa de máscaras y ha luchado con diversas identidades, aunque su máscara principal es la más icónica.
# 3.  **Estilo y Presencia:** Se destacó por su gran agilidad, técnica impecable y una imagen imponente y elegante. A diferencia de otros, mantuvo su máscara durante casi toda su carrera, convirtiéndola en un símbolo de misterio y respeto.
# 4.  **Cine y Cultura Pop:** Debido a su aspecto físico y carisma, apareció en varias películas de acción y lucha libre en los años 60 y 70, lo que ayudó a globalizar la imagen del luchador mexicano.
# 5.  **Legado:** Es considerado un pionero que abrió las puertas para que otros luchadores mexicanos fueran valorados en el extranjero.
#
# En resumen: es un **icono cultural y un maestro del ring** que ayudó a convertir la lucha libre en un fenómeno global.

# %% [markdown]
# # 2. Configuramos el modelo (La "Capa de Abstracción Alta")
# # Esto reemplaza la conexión al 'llm_client' de NVIDIA
